# %%
import os
import random
import tensorflow as tf
import numpy as np

from skimage.io import imread,imshow
from skimage.transform import resize
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
seed = 42
np.random.seed = seed

# %%
IMAGE_WIDTH = 128
IMAGE_HEIGHT = 128
IMAGE_CHANNELS = 3

# %%
train_path = 'data/stage1_train/'
test_path = 'data/stage1_test/'

train_ids = next(os.walk(train_path))[1]
test_ids = next(os.walk(test_path))[1]

X_train = np.zeros((len(train_ids), IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMAGE_HEIGHT, IMAGE_WIDTH, 1), dtype=bool)

# %%
print('Resizing training images and masks')

for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = train_path + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMAGE_CHANNELS]
    img = resize(img, (IMAGE_HEIGHT, IMAGE_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMAGE_HEIGHT, IMAGE_WIDTH, 1), dtype=bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMAGE_HEIGHT, IMAGE_WIDTH), mode='constant', preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask
print('Done!')
# Out:
# Resizing training images and masks
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 670/670 [05:48<00:00,  1.92it/s]
# Done!

# %%
print('Resizing test images')
X_test = np.zeros((len(test_ids), IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), dtype=np.uint8)
sizes_test = []
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = test_path + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMAGE_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMAGE_HEIGHT, IMAGE_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Resizing test images
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 65/65 [00:03<00:00, 18.52it/s]
# Done!

# %%
image_x = random.randint(0, len(train_ids))
imshow(X_train[image_x])
plt.show()
imshow(np.squeeze(Y_train[image_x]))
plt.show()

# %%
inputs = tf.keras.layers.Input(shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS))
s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

# %%
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)

c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)

c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)

c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 16  448         ['input_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 16  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  2320        ['dropout[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 32)   4640        ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 32)   9248        ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 64)   36928       ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 128)  147584      ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)   0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    295168      ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 8, 8, 256)    0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 256)    590080      ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  131200     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 128)  295040      ['concatenate[0][0]']
#
#  dropout_5 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  147584      ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  32832       ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 64)   73792       ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   36928       ['dropout_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  8224        ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 32)   9248        ['dropout_7[0][0]']
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 16  2064       ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 16  2320        ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 1)  17          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Model Checkpoint
checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, save_weights_only=True, verbose=1, save_best_only=True)

# Early Stopping
earlystop = tf.keras.callbacks.EarlyStopping(patience=3, monitor='val_loss')

# Tensorboard
tensorboard = tf.keras.callbacks.TensorBoard(log_dir='logs')

# %%
# Train the model with the new callback
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=50, callbacks=[cp_callback, earlystop, tensorboard])
# Out:
# Epoch 1/50
# 38/38 [==============================] - ETA: 0s - loss: 2.4164 - accuracy: 0.7117
# Epoch 1: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 47s 1s/step - loss: 2.4164 - accuracy: 0.7117 - val_loss: 0.7145 - val_accuracy: 0.8355
# Epoch 2/50
# 38/38 [==============================] - ETA: 0s - loss: 0.7147 - accuracy: 0.8235
# Epoch 2: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 28s 741ms/step - loss: 0.7147 - accuracy: 0.8235 - val_loss: 0.4217 - val_accuracy: 0.8853
# Epoch 3/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3913 - accuracy: 0.8769
# Epoch 3: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 26s 697ms/step - loss: 0.3913 - accuracy: 0.8769 - val_loss: 0.2565 - val_accuracy: 0.8927
# Epoch 4/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2572 - accuracy: 0.9031
# Epoch 4: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 27s 699ms/step - loss: 0.2572 - accuracy: 0.9031 - val_loss: 0.2005 - val_accuracy: 0.9161
# Epoch 5/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2153 - accuracy: 0.9177
# Epoch 5: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 26s 696ms/step - loss: 0.2153 - accuracy: 0.9177 - val_loss: 0.1727 - val_accuracy: 0.9165
# Epoch 6/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9222
# Epoch 6: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 26s 695ms/step - loss: 0.1974 - accuracy: 0.9222 - val_loss: 0.1665 - val_accuracy: 0.9282
# Epoch 7/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1833 - accuracy: 0.9261
# Epoch 7: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 27s 715ms/step - loss: 0.1833 - accuracy: 0.9261 - val_loss: 0.1545 - val_accuracy: 0.9371
# Epoch 8/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1642 - accuracy: 0.9363
# Epoch 8: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 26s 687ms/step - loss: 0.1642 - accuracy: 0.9363 - val_loss: 0.1439 - val_accuracy: 0.9354
# Epoch 9/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1652 - accuracy: 0.9342
# Epoch 9: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 26s 686ms/step - loss: 0.1652 - accuracy: 0.9342 - val_loss: 0.1390 - val_accuracy: 0.9445
# Epoch 10/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1526 - accuracy: 0.9424
# Epoch 10: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 27s 716ms/step - loss: 0.1526 - accuracy: 0.9424 - val_loss: 0.1289 - val_accuracy: 0.9490
# Epoch 11/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.9431
# Epoch 11: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 27s 705ms/step - loss: 0.1499 - accuracy: 0.9431 - val_loss: 0.1254 - val_accuracy: 0.9516
# Epoch 12/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9456
# Epoch 12: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 28s 724ms/step - loss: 0.1443 - accuracy: 0.9456 - val_loss: 0.1210 - val_accuracy: 0.9537
# Epoch 13/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9493
# Epoch 13: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 28s 726ms/step - loss: 0.1397 - accuracy: 0.9493 - val_loss: 0.1193 - val_accuracy: 0.9546
# Epoch 14/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.9522
# Epoch 14: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 29s 766ms/step - loss: 0.1374 - accuracy: 0.9522 - val_loss: 0.1213 - val_accuracy: 0.9548
# Epoch 15/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9528
# Epoch 15: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 28s 730ms/step - loss: 0.1356 - accuracy: 0.9528 - val_loss: 0.1204 - val_accuracy: 0.9546
# Epoch 16/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1275 - accuracy: 0.9555
# Epoch 16: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 27s 709ms/step - loss: 0.1275 - accuracy: 0.9555 - val_loss: 0.1039 - val_accuracy: 0.9606
# Epoch 17/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9553
# Epoch 17: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 27s 698ms/step - loss: 0.1294 - accuracy: 0.9553 - val_loss: 0.1012 - val_accuracy: 0.9620
# Epoch 18/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1195 - accuracy: 0.9590
# Epoch 18: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 27s 712ms/step - loss: 0.1195 - accuracy: 0.9590 - val_loss: 0.1056 - val_accuracy: 0.9607
# Epoch 19/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9590
# Epoch 19: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 28s 749ms/step - loss: 0.1132 - accuracy: 0.9590 - val_loss: 0.0953 - val_accuracy: 0.9624
# Epoch 20/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9603
# Epoch 20: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 28s 731ms/step - loss: 0.1065 - accuracy: 0.9603 - val_loss: 0.0884 - val_accuracy: 0.9639
# Epoch 21/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9609
# Epoch 21: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 29s 759ms/step - loss: 0.1050 - accuracy: 0.9609 - val_loss: 0.0881 - val_accuracy: 0.9646
# Epoch 22/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1056 - accuracy: 0.9606
# Epoch 22: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 29s 762ms/step - loss: 0.1056 - accuracy: 0.9606 - val_loss: 0.0902 - val_accuracy: 0.9644
# Epoch 23/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9623
# Epoch 23: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 29s 769ms/step - loss: 0.1011 - accuracy: 0.9623 - val_loss: 0.0846 - val_accuracy: 0.9655
# Epoch 24/50
# 38/38 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9626
# Epoch 24: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 28s 734ms/step - loss: 0.0993 - accuracy: 0.9626 - val_loss: 0.0939 - val_accuracy: 0.9647
# Epoch 25/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9624
# Epoch 25: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 29s 755ms/step - loss: 0.1011 - accuracy: 0.9624 - val_loss: 0.0861 - val_accuracy: 0.9665
# Epoch 26/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 0.9604
# Epoch 26: saving model to training_1/cp.ckpt
# 38/38 [==============================] - 28s 730ms/step - loss: 0.1008 - accuracy: 0.9604 - val_loss: 0.0868 - val_accuracy: 0.9658
# Epoch 26: early stopping

# %%
idx = random.randint(0, len(X_train))

preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)
# Out:
#  2/19 [==>...........................] - ETA: 3s
# 2023-04-05 16:24:48.096945: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 67108864 exceeds 10% of free system memory.
# 2023-04-05 16:24:48.278356: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 67108864 exceeds 10% of free system memory.
#  3/19 [===>..........................] - ETA: 2s
# 2023-04-05 16:24:48.466469: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 67108864 exceeds 10% of free system memory.
# 2023-04-05 16:24:48.645325: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 67108864 exceeds 10% of free system memory.
#  5/19 [======>.......................] - ETA: 2s
# 2023-04-05 16:24:48.846922: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 67108864 exceeds 10% of free system memory.
# 19/19 [==============================] - 4s 202ms/step
# 3/3 [==============================] - 0s 101ms/step
# 3/3 [==============================] - 0s 99ms/step

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()
# Out:
# /home/sakib/.virtualenvs/unet/lib/python3.10/site-packages/skimage/io/_plugins/matplotlib_plugin.py:149: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()
